# %%
ALL_PATH_CYC = [
    'raw_data/set1_c/monthly/set1c_%smonthly_data_0.txt',
    'raw_data/set2_c/monthly/set2c_%smonthly_data_0.txt',
    'raw_data/set3_c/monthly/set3c_%smonthly_data_0.txt',
    'raw_data/set4_c/monthly/set4c_%smonthly_data_0.txt',
    'raw_data/set5_c/monthly/set5c_%smonthly_data_0.txt',
    'raw_data/set6_c/monthly/set6c_%smonthly_data_0.txt',
    'raw_data/set7_c/monthly/set7c_%smonthly_data_0.txt',
    'raw_data/set8_c/monthly/set8c_%smonthly_data_0.txt',
    'raw_data/set9_c/monthly/set9c_%smonthly_data_0.txt',
    'raw_data/set10_c/monthly/set10c_%smonthly_data_0.txt',
    'raw_data/set11_c/monthly/set11c_%smonthly_data_0.txt',
    'raw_data/set12_c/monthly/set12c_%smonthly_data_0.txt'
]

ALL_PATH_MFT = [
    'raw_data/set1_m/monthly/set1m_%smonthly_data_0.txt',
    'raw_data/set2_m/monthly/set2m_%smonthly_data_0.txt',
    'raw_data/set3_m/monthly/set3m_%smonthly_data_0.txt',
    'raw_data/set4_m/monthly/set4m_%smonthly_data_0.txt',
    'raw_data/set5_m/monthly/set5m_%smonthly_data_0.txt',
    'raw_data/set6_m/monthly/set6m_%smonthly_data_0.txt',
    'raw_data/set7_m/monthly/set7m_%smonthly_data_0.txt',
    'raw_data/set8_m/monthly/set8m_%smonthly_data_0.txt',
    'raw_data/set9_m/monthly/set9m_%smonthly_data_0.txt',
    'raw_data/set10_m/monthly/set10m_%smonthly_data_0.txt',
    'raw_data/set11_m/monthly/set11m_%smonthly_data_0.txt',
    'raw_data/set12_m/monthly/set12m_%smonthly_data_0.txt'
]

ALL_PATH_AC = [
    'raw_data/set1_ac/monthly/set1ac_%smonthly_data_0.txt',
    'raw_data/set2_ac/monthly/set2ac_%smonthly_data_0.txt',
    'raw_data/set3_ac/monthly/set3ac_%smonthly_data_0.txt',
    'raw_data/set4_ac/monthly/set4ac_%smonthly_data_0.txt',
    'raw_data/set5_ac/monthly/set5ac_%smonthly_data_0.txt',
    'raw_data/set6_ac/monthly/set6ac_%smonthly_data_0.txt',
    'raw_data/set7_ac/monthly/set7ac_%smonthly_data_0.txt',
    'raw_data/set8_ac/monthly/set8ac_%smonthly_data_0.txt',
    'raw_data/set9_ac/monthly/set9ac_%smonthly_data_0.txt',
    'raw_data/set10_ac/monthly/set10ac_%smonthly_data_0.txt',
    'raw_data/set11_ac/monthly/set11ac_%smonthly_data_0.txt',
    'raw_data/set12_ac/monthly/set12ac_%smonthly_data_0.txt'
]

ALL_PATH_ALT_AC = [
    'raw_data/alt_init_geno/set1_aac/monthly/set1aac_%smonthly_data_0.txt',
    'raw_data/alt_init_geno/set2_aac/monthly/set2aac_%smonthly_data_0.txt',
    'raw_data/alt_init_geno/set3_aac/monthly/set3aac_%smonthly_data_0.txt',
    'raw_data/alt_init_geno/set4_aac/monthly/set4aac_%smonthly_data_0.txt',
    'raw_data/alt_init_geno/set5_aac/monthly/set5aac_%smonthly_data_0.txt',
    'raw_data/alt_init_geno/set6_aac/monthly/set6aac_%smonthly_data_0.txt',
    'raw_data/alt_init_geno/set7_aac/monthly/set7aac_%smonthly_data_0.txt',
    'raw_data/alt_init_geno/set8_aac/monthly/set8aac_%smonthly_data_0.txt',
    'raw_data/alt_init_geno/set9_aac/monthly/set9aac_%smonthly_data_0.txt',
    'raw_data/alt_init_geno/set10_aac/monthly/set10aac_%smonthly_data_0.txt',
    'raw_data/alt_init_geno/set11_aac/monthly/set11aac_%smonthly_data_0.txt',
    'raw_data/alt_init_geno/set12_aac/monthly/set12aac_%smonthly_data_0.txt'
]

ALL_PATH_NTF_CYC = [
    'raw_data/set1_c/summary/set1c_%ssummary_0.txt',
    'raw_data/set2_c/summary/set2c_%ssummary_0.txt',
    'raw_data/set3_c/summary/set3c_%ssummary_0.txt',
    'raw_data/set4_c/summary/set4c_%ssummary_0.txt',
    'raw_data/set5_c/summary/set5c_%ssummary_0.txt',
    'raw_data/set6_c/summary/set6c_%ssummary_0.txt',
    'raw_data/set7_c/summary/set7c_%ssummary_0.txt',
    'raw_data/set8_c/summary/set8c_%ssummary_0.txt',
    'raw_data/set9_c/summary/set9c_%ssummary_0.txt',
    'raw_data/set10_c/summary/set10c_%ssummary_0.txt',
    'raw_data/set11_c/summary/set11c_%ssummary_0.txt',
    'raw_data/set12_c/summary/set12c_%ssummary_0.txt'
]

ALL_PATH_NTF_MFT = [
    'raw_data/set1_m/summary/set1m_%ssummary_0.txt',
    'raw_data/set2_m/summary/set2m_%ssummary_0.txt',
    'raw_data/set3_m/summary/set3m_%ssummary_0.txt',
    'raw_data/set4_m/summary/set4m_%ssummary_0.txt',
    'raw_data/set5_m/summary/set5m_%ssummary_0.txt',
    'raw_data/set6_m/summary/set6m_%ssummary_0.txt',
    'raw_data/set7_m/summary/set7m_%ssummary_0.txt',
    'raw_data/set8_m/summary/set8m_%ssummary_0.txt',
    'raw_data/set9_m/summary/set9m_%ssummary_0.txt',
    'raw_data/set10_m/summary/set10m_%ssummary_0.txt',
    'raw_data/set11_m/summary/set11m_%ssummary_0.txt',
    'raw_data/set12_m/summary/set12m_%ssummary_0.txt'
]

ALL_PATH_NTF_AC = [
    'raw_data/set1_ac/summary/set1ac_%ssummary_0.txt',
    'raw_data/set2_ac/summary/set2ac_%ssummary_0.txt',
    'raw_data/set3_ac/summary/set3ac_%ssummary_0.txt',
    'raw_data/set4_ac/summary/set4ac_%ssummary_0.txt',
    'raw_data/set5_ac/summary/set5ac_%ssummary_0.txt',
    'raw_data/set6_ac/summary/set6ac_%ssummary_0.txt',
    'raw_data/set7_ac/summary/set7ac_%ssummary_0.txt',
    'raw_data/set8_ac/summary/set8ac_%ssummary_0.txt',
    'raw_data/set9_ac/summary/set9ac_%ssummary_0.txt',
    'raw_data/set10_ac/summary/set10ac_%ssummary_0.txt',
    'raw_data/set11_ac/summary/set11ac_%ssummary_0.txt',
    'raw_data/set12_ac/summary/set12ac_%ssummary_0.txt'
]

ALL_PATH_FIG1_SAVE = [
    'generated_figures/fig1/set1_fig1_PfPR0p1_cov20.svg',
    'generated_figures/fig1/set2_fig1_PfPR1p0_cov20.svg',
    'generated_figures/fig1/set3_fig1_PfPR5p0_cov20.svg',
    'generated_figures/fig1/set4_fig1_PfPR20p0_cov20.svg',
    'generated_figures/fig1/set5_fig1_PfPR0p1_cov40.svg',
    'generated_figures/fig1/set6_fig1_PfPR1p0_cov40.svg',
    'generated_figures/fig1/set7_fig1_PfPR5p0_cov40.svg',
    'generated_figures/fig1/set8_fig1_PfPR20p0_cov40.svg',
    'generated_figures/fig1/set9_fig1_PfPR0p1_cov60.svg',
    'generated_figures/fig1/set10_fig1_PfPR1p0_cov60.svg',
    'generated_figures/fig1/set11_fig1_PfPR5p0_cov60.svg',
    'generated_figures/fig1/set12_fig1_PfPR20p0_cov60.svg'
]

ALL_PATH_FIG2_SAVE = [
    'generated_figures/fig2/set1_fig2_PfPR0p1_cov20.svg',
    'generated_figures/fig2/set2_fig2_PfPR1p0_cov20.svg',
    'generated_figures/fig2/set3_fig2_PfPR5p0_cov20.svg',
    'generated_figures/fig2/set4_fig2_PfPR20p0_cov20.svg',
    'generated_figures/fig2/set5_fig2_PfPR0p1_cov40.svg',
    'generated_figures/fig2/set6_fig2_PfPR1p0_cov40.svg',
    'generated_figures/fig2/set7_fig2_PfPR5p0_cov40.svg',
    'generated_figures/fig2/set8_fig2_PfPR20p0_cov40.svg',
    'generated_figures/fig2/set9_fig2_PfPR0p1_cov60.svg',
    'generated_figures/fig2/set10_fig2_PfPR1p0_cov60.svg',
    'generated_figures/fig2/set11_fig2_PfPR5p0_cov60.svg',
    'generated_figures/fig2/set12_fig2_PfPR20p0_cov60.svg'
]

# %%
from script_1Fig import script_fig1_plotter
for i in range(12):
  script_fig1_plotter(ALL_PATH_AC[i], ALL_PATH_ALT_AC[i], ALL_PATH_FIG1_SAVE[i])

# %%
from script_2Fig import script_fig2_plotter
for i in range(12):
  script_fig2_plotter(ALL_PATH_CYC[i], ALL_PATH_MFT[i], ALL_PATH_AC[i], ALL_PATH_FIG2_SAVE[i], 
                        ALL_PATH_NTF_MFT[i], ALL_PATH_NTF_CYC[i], ALL_PATH_NTF_AC[i])
